# %%
import pandas as pd

# %%
df = pd.read_csv("customer.csv")

# %%
df.head()
# Out:
#    Index      Customer Id First Name Last Name                        Company  \
# 0      1  41cbEFEc7C0B13b   Charlene     Henry  Campbell, Phillips and Melton
# 1      2  41B4AfFF1Cd3d9d      Frank     Miles                      Brown LLC
# 2      3  Ccb4fbCB7FAc18C       Alan     Logan                     Pace-Haley
# 3      4  C344eD15063FEe7     Hailey    Benton                  Ellis-Pearson
# 4      5  99C18CE3aCFFdf9     Tricia    Golden                    Cooke Group
#
#                City          Country               Phone 1  \
# 0   Port Kristopher           Monaco   (023)055-4496x75792
# 1     Schaefershire  Solomon Islands       +1-389-512-9817
# 2      Sandovalstad          Lebanon  001-992-197-5178x663
# 3  West Latoyahaven          Tokelau   +1-406-529-5134x362
# 4      Wilkinsmouth           Angola  001-636-833-5097x802
#
#                  Phone 2                             Email Subscription Date  \
# ...

# %%
df.head(3)
# Out:
#    Index      Customer Id First Name Last Name                        Company  \
# 0      1  41cbEFEc7C0B13b   Charlene     Henry  Campbell, Phillips and Melton
# 1      2  41B4AfFF1Cd3d9d      Frank     Miles                      Brown LLC
# 2      3  Ccb4fbCB7FAc18C       Alan     Logan                     Pace-Haley
#
#               City          Country               Phone 1           Phone 2  \
# 0  Port Kristopher           Monaco   (023)055-4496x75792      427-634-6448
# 1    Schaefershire  Solomon Islands       +1-389-512-9817  631-074-8428x950
# 2     Sandovalstad          Lebanon  001-992-197-5178x663  274-214-0065x796
#
#                      Email Subscription Date              Website
# 0    michele41@collier.com        2021-03-31   https://tapia.com/
# 1  tateaustin@crawford.com        2021-12-28  http://collins.com/
# 2      zproctor@deleon.org        2020-03-10  https://hurley.com/

# %%
df.tail()
# Out:
#           Index      Customer Id First Name  Last Name  \
# 999995   999996  99FF1e9DD4D2916     Autumn     Santos
# 999996   999997  Ba6CF273bbE90B1      Kerri    Stanley
# 999997   999998  5dCAcEcaE6Bcce5     Bailey    Morales
# 999998   999999  625800BFF5FD9d3    Eduardo  Singleton
# 999999  1000000  Fd0a258AA7a7Acc       Alan      Rojas
#
#                            Company           City        Country  \
# 999995     Hoffman, Pena and Brown       Shahfort       Guernsey
# 999996       Wu, Mahoney and Sharp     Arnoldfort  Guinea-Bissau
# 999997   Jensen, Wiggins and Ramos        Tomfurt      Sri Lanka
# 999998                 Hogan Group   New Brettton          Congo
# 999999  Fields, Griffin and Sexton  West Bethland        Lesotho
#
#                       Phone 1             Phone 2  \
# 999995        +1-125-777-2031        089.050.5364
# 999996      (044)335-2869x083          1217199791
# 999997  +1-718-749-5402x63596  642.773.3822x77642
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
list(df.columns)
# Out:
# ['Index',
#  'Customer Id',
#  'First Name',
#  'Last Name',
#  'Company',
#  'City',
#  'Country',
#  'Phone 1',
#  'Phone 2',
#  'Email',
#  'Subscription Date',
#  'Website']

# %%
df["Email"] # to see any column data
# Out:
# 0                     michele41@collier.com
# 1                   tateaustin@crawford.com
# 2                       zproctor@deleon.org
# 3          ronnieharding@gamble-sanford.com
# 4                          qcook@castro.com
#                         ...
# 999995    haleystevens@cummings-holland.net
# 999996               jackpreston@coffey.com
# 999997            sparksgabriel@collier.org
# 999998        katieorozco@hayden-cantu.info
# 999999       megangaines@torres-jenkins.com
# Name: Email, Length: 1000000, dtype: object

# %%
df["Company"]
# Out:
# 0         Campbell, Phillips and Melton
# 1                             Brown LLC
# 2                            Pace-Haley
# 3                         Ellis-Pearson
# 4                           Cooke Group
#                       ...
# 999995          Hoffman, Pena and Brown
# 999996            Wu, Mahoney and Sharp
# 999997        Jensen, Wiggins and Ramos
# 999998                      Hogan Group
# 999999       Fields, Griffin and Sexton
# Name: Company, Length: 1000000, dtype: object

# %%
type(df["Company"])
# Out:
# pandas.core.series.Series

# %%
df[["Company"]]
# Out:
#                               Company
# 0       Campbell, Phillips and Melton
# 1                           Brown LLC
# 2                          Pace-Haley
# 3                       Ellis-Pearson
# 4                         Cooke Group
# ...                               ...
# 999995        Hoffman, Pena and Brown
# 999996          Wu, Mahoney and Sharp
# 999997      Jensen, Wiggins and Ramos
# 999998                    Hogan Group
# 999999     Fields, Griffin and Sexton
#
# [1000000 rows x 1 columns]

# %%
df[["Email"]]
# Out:
#                                     Email
# 0                   michele41@collier.com
# 1                 tateaustin@crawford.com
# 2                     zproctor@deleon.org
# 3        ronnieharding@gamble-sanford.com
# 4                        qcook@castro.com
# ...                                   ...
# 999995  haleystevens@cummings-holland.net
# 999996             jackpreston@coffey.com
# 999997          sparksgabriel@collier.org
# 999998      katieorozco@hayden-cantu.info
# 999999     megangaines@torres-jenkins.com
#
# [1000000 rows x 1 columns]

# %%
type(df[["Email"]])
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns #
# Out:
# Index(['Index', 'Customer Id', 'First Name', 'Last Name', 'Company', 'City',
#        'Country', 'Phone 1', 'Phone 2', 'Email', 'Subscription Date',
#        'Website'],
#       dtype='object')

# %%
df[["Email","Company" , "City"]] #for select multiple columns we used list
# Out:
#                                     Email                        Company  \
# 0                   michele41@collier.com  Campbell, Phillips and Melton
# 1                 tateaustin@crawford.com                      Brown LLC
# 2                     zproctor@deleon.org                     Pace-Haley
# 3        ronnieharding@gamble-sanford.com                  Ellis-Pearson
# 4                        qcook@castro.com                    Cooke Group
# ...                                   ...                            ...
# 999995  haleystevens@cummings-holland.net        Hoffman, Pena and Brown
# 999996             jackpreston@coffey.com          Wu, Mahoney and Sharp
# 999997          sparksgabriel@collier.org      Jensen, Wiggins and Ramos
# 999998      katieorozco@hayden-cantu.info                    Hogan Group
# 999999     megangaines@torres-jenkins.com     Fields, Griffin and Sexton
#
#                     City
# 0        Port Kristopher
# 1          Schaefershire
# ...

# %%
df.dtypes
# Out:
# Index                 int64
# Customer Id          object
# First Name           object
# Last Name            object
# Company              object
# City                 object
# Country              object
# Phone 1              object
# Phone 2              object
# Email                object
# Subscription Date    object
# Website              object
# dtype: object

# %%
df1 = pd.read_excel("students.xlsx")

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
df1.dtypes
# Out:
# Unnamed: 0    float64
# Unnamed: 1     object
# Unnamed: 2     object
# Unnamed: 3     object
# Unnamed: 4     object
# Unnamed: 5     object
# Unnamed: 6     object
# dtype: object

# %%
df1.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6'],
#       dtype='object')

# %%
df1[["Unnamed: 6" ,"Unnamed: 4"]]
# Out:
#     Unnamed: 6                     Unnamed: 4
# 0          NaN                            NaN
# 1          NaN                            NaN
# 2          NaN                            NaN
# 3          NaN                            NaN
# 4          300                            NaN
# 5          NaN                            NaN
# 6   Percentage  Marks in Physics (Out of 100)
# 7     0.843333                             78
# 8     0.913333                             88
# 9          0.8                             82
# 10    0.876667                             85
# 11    0.773333                             80
# 12    0.886667                             92
# 13    0.816667                             79
# 14        0.94                             91
# 15    0.803333                             84
# 16    0.873333                             90
# 17    0.843333                             88
# 18        0.92                             95
# ...

# %%
import requests

# %%
import pandas as pd

# %%
df = pd.read_csv("titanic.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df["Survived"]## select single column
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
type(df["Survived"])
# Out:
# pandas.core.series.Series

# %%
df[['Survived', 'Pclass', 'Name']] # multiple column select
# Out:
#      Survived  Pclass                                               Name
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
# [891 rows x 3 columns]

# %%
df2 = pd.read_csv("baseball.csv")

# %%
df3 = pd.read_csv('dataset.csv')

# %%
df3.head()
# Out:
#    memberNumber        Date   itemDescription
# 0          1808  21-07-2015    tropical fruit
# 1          1808  21-07-2015             candy
# 2          2300  19-09-2015         pip fruit
# 3          1187  12-12-2015  other vegetables
# 4          3037  01-02-2015        whole milk

# %%
df3[['Date']]
# Out:
#              Date
# 0      21-07-2015
# 1      21-07-2015
# 2      19-09-2015
# 3      12-12-2015
# 4      01-02-2015
# ...           ...
# 38760  08-10-2014
# 38761  23-02-2014
# 38762  16-04-2014
# 38763  03-12-2014
# 38764  26-12-2014
#
# [38765 rows x 1 columns]

# %%
df3[['memberNumber','Date','itemDescription']]
# Out:
#        memberNumber        Date        itemDescription
# 0              1808  21-07-2015         tropical fruit
# 1              1808  21-07-2015                  candy
# 2              2300  19-09-2015              pip fruit
# 3              1187  12-12-2015       other vegetables
# 4              3037  01-02-2015             whole milk
# ...             ...         ...                    ...
# 38760          4471  08-10-2014          sliced cheese
# 38761          2022  23-02-2014                  candy
# 38762          1097  16-04-2014               cake bar
# 38763          1510  03-12-2014  fruit/vegetable juice
# 38764          1521  26-12-2014               cat food
#
# [38765 rows x 3 columns]

# %%
type(df3)
# Out:
# pandas.core.frame.DataFrame

# %%
len(df3)
# Out:
# 38765

# %%
df3.columns
# Out:
# Index(['memberNumber', 'Date', 'itemDescription'], dtype='object')

# %%
df3.to_csv("player_data.csv") ##save this data

# %% [markdown]
# ## Part 2 Advance

# %%
df4 = pd.read_csv("titanic.csv")

# %%
df4.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
type(df4)
# Out:
# pandas.core.frame.DataFrame

# %%
df4.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df4.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df4[['Name','Sex','Ticket','Cabin','Embarked']] #cloumn ko seprate krna ke liye
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# ...

# %%
df4.dtypes =='object' ##to check the object kaun kaun sa hai
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name            True
# Sex             True
# Age            False
# SibSp          False
# Parch          False
# Ticket          True
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
df4.dtypes[df4.dtypes=='object'].index
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
type(df4.dtypes[df4.dtypes=='object'])
# Out:
# pandas.core.series.Series

# %%
df4[df4.dtypes[df.dtypes =='object'].index] #object data out
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# ...

# %%
df4[df4.dtypes[df.dtypes =='object'].index].describe()
# Out:
#                            Name   Sex  Ticket Cabin Embarked
# count                       891   891     891   204      889
# unique                      891     2     681   147        3
# top     Braund, Mr. Owen Harris  male  347082    G6        S
# freq                          1   577       7     4      644

# %%
df4.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df4[df4.dtypes[df.dtypes =='float'].index] #float datatpye nikalna
# Out:
#       Age     Fare
# 0    22.0   7.2500
# 1    38.0  71.2833
# 2    26.0   7.9250
# 3    35.0  53.1000
# 4    35.0   8.0500
# ..    ...      ...
# 886  27.0  13.0000
# 887  19.0  30.0000
# 888   NaN  23.4500
# 889  26.0  30.0000
# 890  32.0   7.7500
#
# [891 rows x 2 columns]

# %%
df4[df4.dtypes[df.dtypes =='int64'].index]
# Out:
#      PassengerId  Survived  Pclass  SibSp  Parch
# 0              1         0       3      1      0
# 1              2         1       1      1      0
# 2              3         1       3      0      0
# 3              4         1       1      1      0
# 4              5         0       3      0      0
# ..           ...       ...     ...    ...    ...
# 886          887         0       2      0      0
# 887          888         1       1      0      0
# 888          889         0       3      1      2
# 889          890         1       1      0      0
# 890          891         0       3      0      0
#
# [891 rows x 5 columns]

# %%
df4[['Ticket','Cabin']][4:11:2] #2 ka jumps
# Out:
#      Ticket Cabin
# 4    373450   NaN
# 6     17463   E46
# 8    347742   NaN
# 10  PP 9549    G6

# %%
df4['new_col']=0 # created new column in  the given data/add

# %%
df4
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df4["new_col1"] =df4["PassengerId"]+df4["Pclass"] #create new data with any column

# %%
df4
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df4.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  new_col  new_col1
# 0      0         A/5 21171   7.2500   NaN        S        0         4
# 1      0          PC 17599  71.2833   C85        C        0         3
# 2      0  STON/O2. 3101282   7.9250   NaN        S        0         6
# ...

# %%
pd.Categorical(df4["Pclass"])
# Out:
# [3, 1, 3, 1, 3, ..., 2, 1, 3, 1, 3]
# Length: 891
# Categories (3, int64): [1, 2, 3]

# %%
pd.Categorical(df4["Survived"])
# Out:
# [0, 1, 1, 1, 0, ..., 0, 1, 0, 1, 0]
# Length: 891
# Categories (2, int64): [0, 1]

# %%
df4['Cabin'].unique()
# Out:
# array([nan, 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6',
#        'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33',
#        'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101',
#        'F E69', 'D47', 'B86', 'F2', 'C2', 'E33', 'B19', 'A7', 'C49', 'F4',
#        'A32', 'B4', 'B80', 'A31', 'D36', 'D15', 'C93', 'C78', 'D35',
#        'C87', 'B77', 'E67', 'B94', 'C125', 'C99', 'C118', 'D7', 'A19',
#        'B49', 'D', 'C22 C26', 'C106', 'C65', 'E36', 'C54',
#        'B57 B59 B63 B66', 'C7', 'E34', 'C32', 'B18', 'C124', 'C91', 'E40',
#        'T', 'C128', 'D37', 'B35', 'E50', 'C82', 'B96 B98', 'E10', 'E44',
#        'A34', 'C104', 'C111', 'C92', 'E38', 'D21', 'E12', 'E63', 'A14',
#        'B37', 'C30', 'D20', 'B79', 'E25', 'D46', 'B73', 'C95', 'B38',
#        'B39', 'B22', 'C86', 'C70', 'A16', 'C101', 'C68', 'A10', 'E68',
#        'B41', 'A20', 'D19', 'D50', 'D9', 'A23', 'B50', 'A26', 'D48',
# ...

# %%
df4.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  new_col  new_col1
# 0      0         A/5 21171   7.2500   NaN        S        0         4
# 1      0          PC 17599  71.2833   C85        C        0         3
# 2      0  STON/O2. 3101282   7.9250   NaN        S        0         6
# ...

# %%
df[df4['Age'] >18] #more than 18 years old
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
len(df[df4['Age'] >18])-891
# Out:
# -316

# %%
df4[df4['Fare']>32.204208]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 23            24         1       1
# 27            28         0       1
# ..           ...       ...     ...
# 856          857         1       1
# 863          864         0       3
# 867          868         0       1
# 871          872         1       1
# 879          880         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 23                        Sloper, Mr. William Thompson    male  28.0      0
# 27                      Fortune, Mr. Charles Alexander    male  19.0      3
# ..                                                 ...     ...   ...    ...
# ...

# %%
df4[df4['Fare']==0]
# Out:
#      PassengerId  Survived  Pclass                              Name   Sex  \
# 179          180         0       3               Leonard, Mr. Lionel  male
# 263          264         0       1             Harrison, Mr. William  male
# 271          272         1       3      Tornquist, Mr. William Henry  male
# 277          278         0       2       Parkes, Mr. Francis "Frank"  male
# 302          303         0       3   Johnson, Mr. William Cahoone Jr  male
# 413          414         0       2    Cunningham, Mr. Alfred Fleming  male
# 466          467         0       2             Campbell, Mr. William  male
# 481          482         0       2  Frost, Mr. Anthony Wood "Archie"  male
# 597          598         0       3               Johnson, Mr. Alfred  male
# 633          634         0       1     Parr, Mr. William Henry Marsh  male
# 674          675         0       2        Watson, Mr. Ennis Hastings  male
# ...

# %%
df4[df4['Sex']=='male']
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 0              1         0       3         Braund, Mr. Owen Harris  male
# 4              5         0       3        Allen, Mr. William Henry  male
# 5              6         0       3                Moran, Mr. James  male
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 7              8         0       3  Palsson, Master. Gosta Leonard  male
# ..           ...       ...     ...                             ...   ...
# 883          884         0       2   Banfield, Mr. Frederick James  male
# 884          885         0       3          Sutehall, Mr. Henry Jr  male
# 886          887         0       2           Montvila, Rev. Juozas  male
# 889          890         1       1           Behr, Mr. Karl Howell  male
# 890          891         0       3             Dooley, Mr. Patrick  male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked  new_col  \
# ...

# %%
df4[df4['Sex']=='female']
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 880          881         1       2
# 882          883         0       3
# 885          886         0       3
# 887          888         1       1
# 888          889         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df4[df4['Pclass']==1]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 11            12         1       1
# 23            24         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 23                        Sloper, Mr. William Thompson    male  28.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df4[df4["Survived"]==1]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 875          876         1       3
# 879          880         1       1
# 880          881         1       2
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df4['Sex']=='female'
# Out:
# 0      False
# 1       True
# 2       True
# 3       True
# 4      False
#        ...
# 886    False
# 887     True
# 888     True
# 889    False
# 890    False
# Name: Sex, Length: 891, dtype: bool

# %%
df4[df4['Fare']>32]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 23            24         1       1
# 27            28         0       1
# ..           ...       ...     ...
# 856          857         1       1
# 863          864         0       3
# 867          868         0       1
# 871          872         1       1
# 879          880         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 23                        Sloper, Mr. William Thompson    male  28.0      0
# 27                      Fortune, Mr. Charles Alexander    male  19.0      3
# ..                                                 ...     ...   ...    ...
# ...

# %%
df4[(df4['Sex']=='female') &(df4['Fare']>32)]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 31            32         1       1
# 43            44         1       2
# 52            53         1       1
# ..           ...       ...     ...
# 853          854         1       1
# 856          857         1       1
# 863          864         0       3
# 871          872         1       1
# 879          880         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 31      Spencer, Mrs. William Augustus (Marie Eugenie)  female   NaN      1
# 43            Laroche, Miss. Simonne Marie Anne Andree  female   3.0      1
# 52            Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df4[(df4['Sex']=='female') |(df4['Fare']>32)]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 6              7         0       1
# 8              9         1       3
# ..           ...       ...     ...
# 880          881         1       2
# 882          883         0       3
# 885          886         0       3
# 887          888         1       1
# 888          889         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df4[(df4['Sex']=='male') &(df4['Fare']>32)]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 6              7         0       1               McCarthy, Mr. Timothy J
# 23            24         1       1          Sloper, Mr. William Thompson
# 27            28         0       1        Fortune, Mr. Charles Alexander
# 34            35         0       1               Meyer, Mr. Edgar Joseph
# 35            36         0       1        Holverson, Mr. Alexander Oskar
# ..           ...       ...     ...                                   ...
# 827          828         1       2                 Mallet, Master. Andre
# 838          839         1       3                       Chip, Mr. Chang
# 846          847         0       3              Sage, Mr. Douglas Bullen
# 848          849         0       2                     Harper, Rev. John
# 867          868         0       1  Roebling, Mr. Washington Augustus II
#
#       Sex   Age  SibSp  Parch           Ticket      Fare        Cabin  \
# ...

# %%
df4[df4['Fare']== max(df4['Fare'])]['Name']
# Out:
# 258                      Ward, Miss. Anna
# 679    Cardeza, Mr. Thomas Drake Martinez
# 737                Lesurer, Mr. Gustave J
# Name: Name, dtype: object

# %%
df4.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  new_col  new_col1
# 0      0         A/5 21171   7.2500   NaN        S        0         4
# 1      0          PC 17599  71.2833   C85        C        0         3
# 2      0  STON/O2. 3101282   7.9250   NaN        S        0         6
# ...

# %%
df4[0:2]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked  new_col  new_col1
# 0      0  A/5 21171   7.2500   NaN        S        0         4
# 1      0   PC 17599  71.2833   C85        C        0         3

# %%
df[0::2]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 2              3         1       3
# 4              5         0       3
# 6              7         0       1
# 8              9         1       3
# ..           ...       ...     ...
# 882          883         0       3
# 884          885         0       3
# 886          887         0       2
# 888          889         0       3
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 4                             Allen, Mr. William Henry    male  35.0      0
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df4[['PassengerId',	'Survived'	,'Pclass']][0:2]
# Out:
#    PassengerId  Survived  Pclass
# 0            1         0       3
# 1            2         1       1

# %%
df4.iloc[0:2]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked  new_col  new_col1
# 0      0  A/5 21171   7.2500   NaN        S        0         4
# 1      0   PC 17599  71.2833   C85        C        0         3

# %%
df.loc[0:2,['PassengerId',	'Survived'	,'Pclass']]
# Out:
#    PassengerId  Survived  Pclass
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3

# %%
## Part 3
df4.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'new_col', 'new_col1'],
#       dtype='object')

# %%
s = df4['Name'][0:10]

# %%
s
# Out:
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# 5                                     Moran, Mr. James
# 6                              McCarthy, Mr. Timothy J
# 7                       Palsson, Master. Gosta Leonard
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                  Nasser, Mrs. Nicholas (Adele Achem)
# Name: Name, dtype: object

# %%
len(s)
# Out:
# 10

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
l=['Harshita','b','c','d','e','f','g','h','i','j']

# %%
s1=pd.Series(list(s),index=l)

# %%
s
# Out:
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# 5                                     Moran, Mr. James
# 6                              McCarthy, Mr. Timothy J
# 7                       Palsson, Master. Gosta Leonard
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                  Nasser, Mrs. Nicholas (Adele Achem)
# Name: Name, dtype: object

# %%
s[0]
# Out:
# 'Braund, Mr. Owen Harris'

# %%
s1[0]
# Out:
# C:\Users\panka\AppData\Local\Temp\ipykernel_9224\643609873.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   s1[0]
# 'Braund, Mr. Owen Harris'

# %%
s1["Harshita"]
# Out:
# 'Braund, Mr. Owen Harris'

# %%
s4 = pd.Series([3,4,5,6,6],index=[2,4,5,6,1])

# %%
s5 = pd.Series([34,456,67,8,453] ,index=[9,4,5,6,7])

# %%
s4
# Out:
# 2    3
# 4    4
# 5    5
# 6    6
# 1    6
# dtype: int64

# %%
s6 = pd.concat([s4,s5]) #append fun is not working in pandas 2.0

# %%
s6
# Out:
# 2      3
# 4      4
# 5      5
# 6      6
# 1      6
# 9     34
# 4    456
# 5     67
# 6      8
# 7    453
# dtype: int64

# %%
s6[4]
# Out:
# 4      4
# 4    456
# dtype: int64

# %%
s6[0:5]
# Out:
# 2    3
# 4    4
# 5    5
# 6    6
# 1    6
# dtype: int64

# %%
s4
# Out:
# 2    3
# 4    4
# 5    5
# 6    6
# 1    6
# dtype: int64

# %%
s5
# Out:
# 9     34
# 4    456
# 5     67
# 6      8
# 7    453
# dtype: int64

# %%
s4*s5
# Out:
# 1       NaN
# 2       NaN
# 4    1824.0
# 5     335.0
# 6      48.0
# 7       NaN
# 9       NaN
# dtype: float64

# %%
s4+s5
# Out:
# 1      NaN
# 2      NaN
# 4    460.0
# 5     72.0
# 6     14.0
# 7      NaN
# 9      NaN
# dtype: float64

# %% [markdown]
# ## part 4

# %%
df4.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'new_col', 'new_col1'],
#       dtype='object')

# %%
df4.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  new_col  new_col1
# 0      0         A/5 21171   7.2500   NaN        S        0         4
# 1      0          PC 17599  71.2833   C85        C        0         3
# 2      0  STON/O2. 3101282   7.9250   NaN        S        0         6
# ...

# %%
df4.drop('PassengerId',axis=1,inplace=True) ##delect any coulumns and rows

# %%
df4
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# ...

# %%
df4.drop(3 ,inplace =True) # delete rows concept

# %%
df4
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 4           0       3                           Allen, Mr. William Henry
# 5           0       3                                   Moran, Mr. James
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# ...

# %%
df4.set_index("Name" ,inplace=True) #any columns and rows convert into index form used in method

# %%
df4
# Out:
#                                                     Survived  Pclass     Sex  \
# Name
# Braund, Mr. Owen Harris                                    0       3    male
# Cumings, Mrs. John Bradley (Florence Briggs Tha...         1       1  female
# Heikkinen, Miss. Laina                                     1       3  female
# Allen, Mr. William Henry                                   0       3    male
# Moran, Mr. James                                           0       3    male
# ...                                                      ...     ...     ...
# Montvila, Rev. Juozas                                      0       2    male
# Graham, Miss. Margaret Edith                               1       1  female
# Johnston, Miss. Catherine Helen "Carrie"                   0       3  female
# Behr, Mr. Karl Howell                                      1       1    male
# Dooley, Mr. Patrick                                        0       3    male
#
# ...

# %%
df4.reset_index() # return all data
# Out:
#                                                   Name  Survived  Pclass  \
# 0                              Braund, Mr. Owen Harris         0       3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                               Heikkinen, Miss. Laina         1       3
# 3                             Allen, Mr. William Henry         0       3
# 4                                     Moran, Mr. James         0       3
# ..                                                 ...       ...     ...
# 885                              Montvila, Rev. Juozas         0       2
# 886                       Graham, Miss. Margaret Edith         1       1
# 887           Johnston, Miss. Catherine Helen "Carrie"         0       3
# 888                              Behr, Mr. Karl Howell         1       1
# 889                                Dooley, Mr. Patrick         0       3
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# ...

# %%
d ={'key1':[3,4,5,6,7],
    'key2':[5,6,7,8,6],
    'key3':[9,8,4,5,3]
    
    
}

# %%
pd.DataFrame(d)
# Out:
#    key1  key2  key3
# 0     3     5     9
# 1     4     6     8
# 2     5     7     4
# 3     6     8     5
# 4     7     6     3

# %%
import pandas as pd

# %%
df = pd.read_csv("Fifa.csv")

# %%
df.head()
# Out:
#   player_id       player_name  age nationality   team  jersey_number  \
# 0    P00055        Rodri Fati   26     Spanish  Spain              3
# 1    P00070   Ansu Le Normand   19     Spanish  Spain             18
# 2    P00066        Gavi Ramos   18     Spanish  Spain             14
# 3    P00073     Pedro Cubarsi   20     Spanish  Spain             21
# 4    P00059  Alvaro Oyarzabal   23     Spanish  Spain              7
#
#      position  height_cm  weight_kg preferred_foot  ... possession_impact  \
# 0  Goalkeeper        195         75           Left  ...               1.1
# 1  Midfielder        178         75          Right  ...               3.5
# 2  Midfielder        177         72           Left  ...              15.3
# 3     Forward        182         74          Right  ...               1.2
# 4    Defender        191         81           Left  ...               6.2
#
#    pressure_resistance creativity_score consistency_score  \
# ...

# %%
df[['player_id','position']]
# Out:
#       player_id    position
# 0        P00055  Goalkeeper
# 1        P00070  Midfielder
# 2        P00066  Midfielder
# 3        P00073     Forward
# 4        P00059    Defender
# ...         ...         ...
# 54595    P00996    Defender
# 54596    P01006  Midfielder
# 54597    P01008  Midfielder
# 54598    P00991  Goalkeeper
# 54599    P00989  Goalkeeper
#
# [54600 rows x 2 columns]

# %%
df.tail()
# Out:
#       player_id       player_name  age nationality  team  jersey_number  \
# 54595    P00996       Amir Younis   28       Iraqi  Iraq              8
# 54596    P01006  Safaa Al-Khafaji   20       Iraqi  Iraq             18
# 54597    P01008     Ahmed Hussein   26       Iraqi  Iraq             20
# 54598    P00991     Ibrahim Mhawi   30       Iraqi  Iraq              3
# 54599    P00989  Mohannad Hussein   27       Iraqi  Iraq              1
#
#          position  height_cm  weight_kg preferred_foot  ... possession_impact  \
# 54595    Defender        177         73          Right  ...               0.0
# 54596  Midfielder        176         72          Right  ...               0.0
# 54597  Midfielder        173         77           Left  ...               0.0
# 54598  Goalkeeper        190         81          Right  ...               0.0
# 54599  Goalkeeper        187         73          Right  ...               0.0
#
# ...

# %%
df
# Out:
#       player_id       player_name  age nationality   team  jersey_number  \
# 0        P00055        Rodri Fati   26     Spanish  Spain              3
# 1        P00070   Ansu Le Normand   19     Spanish  Spain             18
# 2        P00066        Gavi Ramos   18     Spanish  Spain             14
# 3        P00073     Pedro Cubarsi   20     Spanish  Spain             21
# 4        P00059  Alvaro Oyarzabal   23     Spanish  Spain              7
# ...         ...               ...  ...         ...    ...            ...
# 54595    P00996       Amir Younis   28       Iraqi   Iraq              8
# 54596    P01006  Safaa Al-Khafaji   20       Iraqi   Iraq             18
# 54597    P01008     Ahmed Hussein   26       Iraqi   Iraq             20
# 54598    P00991     Ibrahim Mhawi   30       Iraqi   Iraq              3
# 54599    P00989  Mohannad Hussein   27       Iraqi   Iraq              1
#
#          position  height_cm  weight_kg preferred_foot  ... possession_impact  \
# ...

# %%
df.max()['age']
# Out:
# np.int64(39)

# %%
df.min()['age']
# Out:
# np.int64(17)

# %%
df.max()['clutch_performance_score']
# Out:
# np.float64(99.0)

# %%
df.max()['total_goals_tournament']
# Out:
# np.int64(10)

# %%
df9=df[['player_id','player_name','age']][0:5]

# %%
df7= df[['player_id','player_name','age']][5:10]

# %%
df7
# Out:
#   player_id      player_name  age
# 5    P00072        Dani Gavi   21
# 6    P00058    Rodri Laporte   27
# 7    P00078        Ansu Fati   27
# 8    P00056     Pedro Torres   24
# 9    P00074  Gavi Le Normand   25

# %%
df9
# Out:
#   player_id       player_name  age
# 0    P00055        Rodri Fati   26
# 1    P00070   Ansu Le Normand   19
# 2    P00066        Gavi Ramos   18
# 3    P00073     Pedro Cubarsi   20
# 4    P00059  Alvaro Oyarzabal   23

# %%
df8=pd.concat([df9,df7],axis=1) #merge opertaion perform

# %%
df8.fillna("Harshita")##fill in place nan
# Out:
#   player_id       player_name       age player_id      player_name       age
# 0    P00055        Rodri Fati      26.0  Harshita         Harshita  Harshita
# 1    P00070   Ansu Le Normand      19.0  Harshita         Harshita  Harshita
# 2    P00066        Gavi Ramos      18.0  Harshita         Harshita  Harshita
# 3    P00073     Pedro Cubarsi      20.0  Harshita         Harshita  Harshita
# 4    P00059  Alvaro Oyarzabal      23.0  Harshita         Harshita  Harshita
# 5  Harshita          Harshita  Harshita    P00072        Dani Gavi      21.0
# 6  Harshita          Harshita  Harshita    P00058    Rodri Laporte      27.0
# 7  Harshita          Harshita  Harshita    P00078        Ansu Fati      27.0
# 8  Harshita          Harshita  Harshita    P00056     Pedro Torres      24.0
# 9  Harshita          Harshita  Harshita    P00074  Gavi Le Normand      25.0

# %%
data1=pd.DataFrame({'key1':[1,2,4,5,6],
                    'key2':[4,5,6,7,8],
                    'key3':[3,4,5,6,6]
    
})

# %%
data1
# Out:
#    key1  key2  key3
# 0     1     4     3
# 1     2     5     4
# 2     4     6     5
# 3     5     7     6
# 4     6     8     6

# %%
data2=pd.DataFrame({'key1':[1,2,45,5,67],
                    'key4':[4,5,6,70,8],
                    'key5':[3,4,57,6,6]
    
})

# %%
data2
# Out:
#    key1  key4  key5
# 0     1     4     3
# 1     2     5     4
# 2    45     6    57
# 3     5    70     6
# 4    67     8     6

# %%
pd.merge(data1,data2)
# Out:
#    key1  key2  key3  key4  key5
# 0     1     4     3     4     3
# 1     2     5     4     5     4
# 2     5     7     6    70     6

# %%
pd.merge(data1,data2,how='left')
# Out:
#    key1  key2  key3  key4  key5
# 0     1     4     3   4.0   3.0
# 1     2     5     4   5.0   4.0
# 2     4     6     5   NaN   NaN
# 3     5     7     6  70.0   6.0
# 4     6     8     6   NaN   NaN

# %%
pd.merge(data1,data2,how='right')
# Out:
#    key1  key2  key3  key4  key5
# 0     1   4.0   3.0     4     3
# 1     2   5.0   4.0     5     4
# 2    45   NaN   NaN     6    57
# 3     5   7.0   6.0    70     6
# 4    67   NaN   NaN     8     6

# %%
pd.merge(data1,data2,how='cross')
# Out:
#     key1_x  key2  key3  key1_y  key4  key5
# 0        1     4     3       1     4     3
# 1        1     4     3       2     5     4
# 2        1     4     3      45     6    57
# 3        1     4     3       5    70     6
# 4        1     4     3      67     8     6
# 5        2     5     4       1     4     3
# 6        2     5     4       2     5     4
# 7        2     5     4      45     6    57
# 8        2     5     4       5    70     6
# 9        2     5     4      67     8     6
# 10       4     6     5       1     4     3
# 11       4     6     5       2     5     4
# 12       4     6     5      45     6    57
# 13       4     6     5       5    70     6
# 14       4     6     5      67     8     6
# 15       5     7     6       1     4     3
# 16       5     7     6       2     5     4
# 17       5     7     6      45     6    57
# 18       5     7     6       5    70     6
# 19       5     7     6      67     8     6
# 20       6     8     6       1     4     3
# ...

# %%
pd.merge(data1,data2,how='right',on='key1')
# Out:
#    key1  key2  key3  key4  key5
# 0     1   4.0   3.0     4     3
# 1     2   5.0   4.0     5     4
# 2    45   NaN   NaN     6    57
# 3     5   7.0   6.0    70     6
# 4    67   NaN   NaN     8     6

# %%
data1=pd.DataFrame({'key1':[1,2,45,5,67],
                    'key4':[4,5,6,70,8],
                    'key5':[3,4,57,6,6]},
                    index=['a','b','c','d','e']
    
)

# %%
data2=pd.DataFrame({'key13':[1,2,45,5,67],
                    'key44':[4,5,6,70,8],
                    'key54':[3,4,57,6,6]},
                   index=['e','f','g','h','i']
    
)

# %%
data1
# Out:
#    key1  key4  key5
# a     1     4     3
# b     2     5     4
# c    45     6    57
# d     5    70     6
# e    67     8     6

# %%
data2
# Out:
#    key13  key44  key54
# e      1      4      3
# f      2      5      4
# g     45      6     57
# h      5     70      6
# i     67      8      6

# %%
data1.join(data2)
# Out:
#    key1  key4  key5  key13  key44  key54
# a     1     4     3    NaN    NaN    NaN
# b     2     5     4    NaN    NaN    NaN
# c    45     6    57    NaN    NaN    NaN
# d     5    70     6    NaN    NaN    NaN
# e    67     8     6    1.0    4.0    3.0

# %%
data1.join(data2 , how='right')
# Out:
#    key1  key4  key5  key13  key44  key54
# e  67.0   8.0   6.0      1      4      3
# f   NaN   NaN   NaN      2      5      4
# g   NaN   NaN   NaN     45      6     57
# h   NaN   NaN   NaN      5     70      6
# i   NaN   NaN   NaN     67      8      6

# %%
data1.join(data2,how='outer')
# Out:
#    key1  key4  key5  key13  key44  key54
# a   1.0   4.0   3.0    NaN    NaN    NaN
# b   2.0   5.0   4.0    NaN    NaN    NaN
# c  45.0   6.0  57.0    NaN    NaN    NaN
# d   5.0  70.0   6.0    NaN    NaN    NaN
# e  67.0   8.0   6.0    1.0    4.0    3.0
# f   NaN   NaN   NaN    2.0    5.0    4.0
# g   NaN   NaN   NaN   45.0    6.0   57.0
# h   NaN   NaN   NaN    5.0   70.0    6.0
# i   NaN   NaN   NaN   67.0    8.0    6.0

# %%
data1.join(data2,how='cross')
# Out:
#     key1  key4  key5  key13  key44  key54
# 0      1     4     3      1      4      3
# 1      1     4     3      2      5      4
# 2      1     4     3     45      6     57
# 3      1     4     3      5     70      6
# 4      1     4     3     67      8      6
# 5      2     5     4      1      4      3
# 6      2     5     4      2      5      4
# 7      2     5     4     45      6     57
# 8      2     5     4      5     70      6
# 9      2     5     4     67      8      6
# 10    45     6    57      1      4      3
# 11    45     6    57      2      5      4
# 12    45     6    57     45      6     57
# 13    45     6    57      5     70      6
# 14    45     6    57     67      8      6
# 15     5    70     6      1      4      3
# 16     5    70     6      2      5      4
# 17     5    70     6     45      6     57
# 18     5    70     6      5     70      6
# 19     5    70     6     67      8      6
# 20    67     8     6      1      4      3
# ...

# %%
df
# Out:
#       player_id       player_name  age nationality   team  jersey_number  \
# 0        P00055        Rodri Fati   26     Spanish  Spain              3
# 1        P00070   Ansu Le Normand   19     Spanish  Spain             18
# 2        P00066        Gavi Ramos   18     Spanish  Spain             14
# 3        P00073     Pedro Cubarsi   20     Spanish  Spain             21
# 4        P00059  Alvaro Oyarzabal   23     Spanish  Spain              7
# ...         ...               ...  ...         ...    ...            ...
# 54595    P00996       Amir Younis   28       Iraqi   Iraq              8
# 54596    P01006  Safaa Al-Khafaji   20       Iraqi   Iraq             18
# 54597    P01008     Ahmed Hussein   26       Iraqi   Iraq             20
# 54598    P00991     Ibrahim Mhawi   30       Iraqi   Iraq              3
# 54599    P00989  Mohannad Hussein   27       Iraqi   Iraq              1
#
#          position  height_cm  weight_kg preferred_foot  ... possession_impact  \
# ...

# %%
df.drop('player_of_match_awards',axis=1)
# Out:
#       player_id       player_name  age nationality   team  jersey_number  \
# 0        P00055        Rodri Fati   26     Spanish  Spain              3
# 1        P00070   Ansu Le Normand   19     Spanish  Spain             18
# 2        P00066        Gavi Ramos   18     Spanish  Spain             14
# 3        P00073     Pedro Cubarsi   20     Spanish  Spain             21
# 4        P00059  Alvaro Oyarzabal   23     Spanish  Spain              7
# ...         ...               ...  ...         ...    ...            ...
# 54595    P00996       Amir Younis   28       Iraqi   Iraq              8
# 54596    P01006  Safaa Al-Khafaji   20       Iraqi   Iraq             18
# 54597    P01008     Ahmed Hussein   26       Iraqi   Iraq             20
# 54598    P00991     Ibrahim Mhawi   30       Iraqi   Iraq              3
# 54599    P00989  Mohannad Hussein   27       Iraqi   Iraq              1
#
#          position  height_cm  weight_kg preferred_foot  ...  \
# ...

# %%
df['player_name_len']=df['player_name'].apply(len)#count len of name players

# %%
df.head()
# Out:
#   player_id       player_name  age nationality   team  jersey_number  \
# 0    P00055        Rodri Fati   26     Spanish  Spain              3
# 1    P00070   Ansu Le Normand   19     Spanish  Spain             18
# 2    P00066        Gavi Ramos   18     Spanish  Spain             14
# 3    P00073     Pedro Cubarsi   20     Spanish  Spain             21
# 4    P00059  Alvaro Oyarzabal   23     Spanish  Spain              7
#
#      position  height_cm  weight_kg preferred_foot  ... pressure_resistance  \
# 0  Goalkeeper        195         75           Left  ...                44.2
# 1  Midfielder        178         75          Right  ...                38.2
# 2  Midfielder        177         72           Left  ...                99.0
# 3     Forward        182         74          Right  ...                19.8
# 4    Defender        191         81           Left  ...                44.1
#
#    creativity_score consistency_score clutch_performance_score  \
# ...
