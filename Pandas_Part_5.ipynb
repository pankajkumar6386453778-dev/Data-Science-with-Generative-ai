# %%
import pandas as pd

# %%
data ={'a':[1,2,3,4],
       'b':[4,5,6,7],
       'c':['sudh','krish','hitesh','navin']
    
}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#    a  b       c
# 0  1  4    sudh
# 1  2  5   krish
# 2  3  6  hitesh
# 3  4  7   navin

# %%
df.set_index('a',inplace=True)

# %%
df
# Out:
#    b       c
# a
# 1  4    sudh
# 2  5   krish
# 3  6  hitesh
# 4  7   navin

# %%
df = df.reset_index()

# %%
df
# Out:
#    a  b       c
# 0  1  4    sudh
# 1  2  5   krish
# 2  3  6  hitesh
# 3  4  7   navin

# %%
data ={'a':[1,2,3,4],
       'b':[4,5,6,7],
       'c':['sudh','krish','hitesh','navin']
    
}
df1=pd.DataFrame(data,index=['a','b','c','d'])# give index by itself

# %%
df1
# Out:
#    a  b       c
# a  1  4    sudh
# b  2  5   krish
# c  3  6  hitesh
# d  4  7   navin

# %%
df1.reindex(['b','c','d','a'])
# Out:
#    a  b       c
# b  2  5   krish
# c  3  6  hitesh
# d  4  7   navin
# a  1  4    sudh

# %%
df1
# Out:
#    a  b       c
# a  1  4    sudh
# b  2  5   krish
# c  3  6  hitesh
# d  4  7   navin

# %%
for i,j in df1.iterrows():
    print(j)
# Out:
# a       1
# b       4
# c    sudh
# Name: a, dtype: object
# a        2
# b        5
# c    krish
# Name: b, dtype: object
# a         3
# b         6
# c    hitesh
# Name: c, dtype: object
# a        4
# b        7
# c    navin
# Name: d, dtype: object

# %%
df1
# Out:
#    a  b       c
# a  1  4    sudh
# b  2  5   krish
# c  3  6  hitesh
# d  4  7   navin

# %%
[i for i in df['a']]
# Out:
# [1, 2, 3, 4]

# %%
list(df['a'])
# Out:
# [1, 2, 3, 4]

# %%
def test(x):
    return x.sum()
df1.apply(test, axis=0)
# Out:
# a                      10
# b                      22
# c    sudhkrishhiteshnavin
# dtype: object

# %%
df2 =df1[['a','b']]

# %%
df2
# Out:
#    a  b
# a  1  4
# b  2  5
# c  3  6
# d  4  7

# %%
df2.applymap(lambda x:x**2) ## whole data included
# Out:
# C:\Users\panka\AppData\Local\Temp\ipykernel_16704\4189297917.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df2.applymap(lambda x:x**2) ## whole data included
#     a   b
# a   1  16
# b   4  25
# c   9  36
# d  16  49

# %%
df.sort_values('c')
# Out:
#    a  b       c
# 2  3  6  hitesh
# 1  2  5   krish
# 3  4  7   navin
# 0  1  4    sudh

# %%
df.sort_index(ascending =False)
# Out:
#    a  b       c
# 3  4  7   navin
# 2  3  6  hitesh
# 1  2  5   krish
# 0  1  4    sudh

# %%
t = "i use to teach data science"
len(t.split())
# Out:
# 6

# %%
df
# Out:
#    a  b       c
# 0  1  4    sudh
# 1  2  5   krish
# 2  3  6  hitesh
# 3  4  7   navin

# %%
df['a'][0]
# Out:
# np.int64(1)

# %%
df['a'].mean()
# Out:
# np.float64(2.5)

# %%
df['a'].mode()
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# Name: a, dtype: int64

# %%
df['a'].median()
# Out:
# np.float64(2.5)

# %%
df['a'].std()
# Out:
# np.float64(1.2909944487358056)

# %%
df['a'].sum()
# Out:
# np.int64(10)

# %%
df['a'].min()
# Out:
# np.int64(1)

# %%
df['a'].max()
# Out:
# np.int64(4)

# %%
df['a'].var()
# Out:
# np.float64(1.6666666666666667)

# %%
#Python Pandas -Window Functions
df8 =pd.DataFrame({'a':[3,4,5,2,1,3,4,5,6]})

# %%
df8
# Out:
#    a
# 0  3
# 1  4
# 2  5
# 3  2
# 4  1
# 5  3
# 6  4
# 7  5
# 8  6

# %%
df8['a'].rolling(window=2).mean()
# Out:
# 0    NaN
# 1    3.5
# 2    4.5
# 3    3.5
# 4    1.5
# 5    2.0
# 6    3.5
# 7    4.5
# 8    5.5
# Name: a, dtype: float64

# %%
df8['a'].rolling(window=1).mean()
# Out:
# 0    3.0
# 1    4.0
# 2    5.0
# 3    2.0
# 4    1.0
# 5    3.0
# 6    4.0
# 7    5.0
# 8    6.0
# Name: a, dtype: float64

# %%
df8['a'].rolling(window=3).mean()
# Out:
# 0         NaN
# 1         NaN
# 2    4.000000
# 3    3.666667
# 4    2.666667
# 5    2.000000
# 6    2.666667
# 7    4.000000
# 8    5.000000
# Name: a, dtype: float64

# %%
df8['a'].rolling(window=2).sum()
# Out:
# 0     NaN
# 1     7.0
# 2     9.0
# 3     7.0
# 4     3.0
# 5     4.0
# 6     7.0
# 7     9.0
# 8    11.0
# Name: a, dtype: float64

# %%
df8['a'].rolling(window=2).min()
# Out:
# 0    NaN
# 1    3.0
# 2    4.0
# 3    2.0
# 4    1.0
# 5    1.0
# 6    3.0
# 7    4.0
# 8    5.0
# Name: a, dtype: float64

# %%
df8['a'].rolling(window=2).max()
# Out:
# 0    NaN
# 1    4.0
# 2    5.0
# 3    5.0
# 4    2.0
# 5    3.0
# 6    4.0
# 7    5.0
# 8    6.0
# Name: a, dtype: float64

# %%
df8['a'].cumsum()
# Out:
# 0     3
# 1     7
# 2    12
# 3    14
# 4    15
# 5    18
# 6    22
# 7    27
# 8    33
# Name: a, dtype: int64

# %% [markdown]
# ## Python Pandas -Date  Functionality

# %%
date =pd.date_range(start='2023-04-23',end='2023-06-23')

# %%
date
# Out:
# DatetimeIndex(['2023-04-23', '2023-04-24', '2023-04-25', '2023-04-26',
#                '2023-04-27', '2023-04-28', '2023-04-29', '2023-04-30',
#                '2023-05-01', '2023-05-02', '2023-05-03', '2023-05-04',
#                '2023-05-05', '2023-05-06', '2023-05-07', '2023-05-08',
#                '2023-05-09', '2023-05-10', '2023-05-11', '2023-05-12',
#                '2023-05-13', '2023-05-14', '2023-05-15', '2023-05-16',
#                '2023-05-17', '2023-05-18', '2023-05-19', '2023-05-20',
#                '2023-05-21', '2023-05-22', '2023-05-23', '2023-05-24',
#                '2023-05-25', '2023-05-26', '2023-05-27', '2023-05-28',
#                '2023-05-29', '2023-05-30', '2023-05-31', '2023-06-01',
#                '2023-06-02', '2023-06-03', '2023-06-04', '2023-06-05',
#                '2023-06-06', '2023-06-07', '2023-06-08', '2023-06-09',
#                '2023-06-10', '2023-06-11', '2023-06-12', '2023-06-13',
# ...

# %%
df_date = pd.DataFrame({'date':date})

# %%
df_date
# Out:
#          date
# 0  2023-04-23
# 1  2023-04-24
# 2  2023-04-25
# 3  2023-04-26
# 4  2023-04-27
# ..        ...
# 57 2023-06-19
# 58 2023-06-20
# 59 2023-06-21
# 60 2023-06-22
# 61 2023-06-23
#
# [62 rows x 1 columns]

# %%
df_date.dtypes
# Out:
# date    datetime64[ns]
# dtype: object

# %%
df4= pd.DataFrame({"date":['2023-06-23','2023-06-22','2023-06-20']})

# %%
df4
# Out:
#          date
# 0  2023-06-23
# 1  2023-06-22
# 2  2023-06-20

# %%
df4.dtypes
# Out:
# date    object
# dtype: object

# %%
df4['updated_date']=pd.to_datetime(df4['date']) #convert at any point of time

# %%
df4
# Out:
#          date updated_date
# 0  2023-06-23   2023-06-23
# 1  2023-06-22   2023-06-22
# 2  2023-06-20   2023-06-20

# %%
df4.dtypes
# Out:
# date                    object
# updated_date    datetime64[ns]
# dtype: object

# %%
df4['year'] =df4['updated_date'].dt.year

# %%
df4
# Out:
#          date updated_date  year
# 0  2023-06-23   2023-06-23  2023
# 1  2023-06-22   2023-06-22  2023
# 2  2023-06-20   2023-06-20  2023

# %%
df4['month'] =df4['updated_date'].dt.month

# %%
df4
# Out:
#          date updated_date  year  month
# 0  2023-06-23   2023-06-23  2023      6
# 1  2023-06-22   2023-06-22  2023      6
# 2  2023-06-20   2023-06-20  2023      6

# %% [markdown]
# ## Python Pandas _Time Delta

# %%
pd.Timedelta(days=1 , hours =5 ,minutes =45)
# Out:
# Timedelta('1 days 05:45:00')

# %%
dt = pd.to_datetime('2023-06-20')

# %%
td =pd.Timedelta(days=1)

# %%
dt+td
# Out:
# Timestamp('2023-06-21 00:00:00')

# %% [markdown]
# # Python Pandas - Categorical Data

# %%
data =["Pankaj","Harshita","Hema","Pankhi"]

# %%
cat = pd.Categorical(data)

# %%
cat
# Out:
# ['Pankaj', 'Harshita', 'Hema', 'Pankhi']
# Categories (4, object): ['Harshita', 'Hema', 'Pankaj', 'Pankhi']

# %%
cat.value_counts()
# Out:
# Harshita    1
# Hema        1
# Pankaj      1
# Pankhi      1
# Name: count, dtype: int64

# %% [markdown]
# ## Python Pandas - Visualization

# %%
d = pd.Series([1,2,3,3,5,6,6,8])

# %%
d
# Out:
# 0    1
# 1    2
# 2    3
# 3    3
# 4    5
# 5    6
# 6    6
# 7    8
# dtype: int64

# %%
d.plot()
# Out:
# <Axes: >

# %%
df =pd.DataFrame({'a':[3,4,5,6,7],
                  'b':[4,5,6,7,8]
    
})

# %%
df
# Out:
#    a  b
# 0  3  4
# 1  4  5
# 2  5  6
# 3  6  7
# 4  7  8

# %%
df.plot()
# Out:
# <Axes: >

# %%
df.plot(x='a',y='b')
# Out:
# <Axes: xlabel='a'>

# %%
df.plot.scatter(x='a',y='b')
# Out:
# <Axes: xlabel='a', ylabel='b'>

# %%
d = pd.Series([1,2,3,3,5,6,6,8])

# %%
d
# Out:
# 0    1
# 1    2
# 2    3
# 3    3
# 4    5
# 5    6
# 6    6
# 7    8
# dtype: int64

# %%
d.plot.pie()
# Out:
# <Axes: >
